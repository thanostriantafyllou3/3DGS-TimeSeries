# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
gaussian_experiment = True

if gaussian_experiment:
    csv_path = '/home/anthosmakris/GS_exp/GS4Time/data/time_series/chair/gaussian_noise_samples.csv'
else:   
    csv_path = '/home/thanostriantafyllou/GS4Time/data/time_series/chair/sine_wave_samples.csv'


df = pd.read_csv(csv_path, index_col='period')

# Display the DataFrame
df.head()
# Out:
#         sample_0  sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  \
# period
# 30      0.879922  0.615382  0.727603  0.972409  0.899997  0.348217  0.722046
# 31      0.602487  0.827558  0.497976  0.598491  0.372109  0.042594  0.664543
# 32      0.567822  0.611116  0.365575  0.153576  0.470288  0.568094  0.776394
# 33      0.452800  0.294778  0.688569  0.224739  0.496506  0.364085  0.612812
# 34      0.407339  0.468030  0.380052  0.202941  0.572182  0.459840  0.221577
#
#         sample_7  sample_8  sample_9  sample_10  sample_11  sample_12  \
# period
# 30      0.508411  0.517748  0.617408   0.565707   0.819837   0.685378
# 31      0.705433  0.393819  0.978007   0.255682   0.546644   0.501462
# 32      0.770980  0.462643  0.479134   0.334392   0.262344   0.206823
# 33      0.438693  0.308775  0.532302   0.620847   0.550670   0.596435
# 34      0.627529  0.361790  0.547844   0.679182   0.562786   0.758765
#
#         sample_13  sample_14
# period
# ...

# %%
# Concatenate all the samples into a single sequence
whole_signal = df.values.flatten()

# Generate a time index for the whole signal
time_index = np.arange(len(whole_signal))

# Number of samples per window
samples_per_period = df.shape[1]

# Use a colormap
cmap = plt.get_cmap('tab20')
colors = cmap(np.linspace(0, 1, df.shape[0]))

# Plot the whole sine wave signal with colored windows
plt.figure(figsize=(12, 6))

# Plot the entire signal
plt.plot(time_index, whole_signal, color='black')
plt.scatter(time_index, whole_signal, color='black', s=5)

# Shade the background for each window
for i in range(df.shape[0]):
    start_idx = i * samples_per_period
    end_idx = (i + 1) * samples_per_period
    plt.axvspan(start_idx, end_idx, facecolor=colors[i], alpha=0.3)

plt.xlabel('Sample Index')
plt.ylabel('Sine Value')
plt.title('Whole Sine Wave Signal with Colored Windows')
plt.grid(True)
plt.show()
