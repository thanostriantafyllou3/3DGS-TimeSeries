# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Configurations
signal_dir = '/home/thanostriantafyllou/GS4Time/data/time_series/chair'

# %%
signal_csv_path = os.path.join(signal_dir, 'gt_signal.csv')
df = pd.read_csv(signal_csv_path, index_col='period')

# Display the DataFrame
df.head()
# Out:
#         sample_0  sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  \
# period
# 30      0.500000  0.704011  0.872514  0.976180  0.996967  0.931257  0.790486
# 31      0.510506  0.713558  0.879439  0.979279  0.995701  0.925845  0.781871
# 32      0.521008  0.723011  0.886198  0.982167  0.994215  0.920245  0.773131
# 33      0.531501  0.732365  0.892786  0.984842  0.992512  0.914459  0.764270
# 34      0.541979  0.741616  0.899200  0.987303  0.990591  0.908491  0.755293
#
#         sample_7  sample_8  sample_9  sample_10  sample_11  sample_12  \
# period
# 30      0.599156  0.390568  0.201027   0.063522   0.001986   0.027130
# 31      0.588837  0.380341  0.192671   0.058493   0.001159   0.030648
# 32      0.578478  0.370166  0.184452   0.053659   0.000552   0.034374
# 33      0.568084  0.360049  0.176371   0.049022   0.000166   0.038306
# 34      0.557661  0.349993  0.168434   0.044584   0.000000   0.042441
#
#         sample_13  sample_14
# period
# ...

# %%
# Ground truth signal
gt_signal = df.values.flatten()

time_index = np.arange(len(gt_signal))

# Number of samples per window
window_size = df.shape[1]

# Plot of the ground truth signal generated
plt.figure(figsize=(12, 6))

plt.plot(time_index, gt_signal, color='black')
plt.scatter(time_index, gt_signal, color='black', s=5)

# Shade the background for each window
# WHITE: train region, 
# BLUE: test region
background_colors = ['white', 'blue']
for i in range(df.shape[0]):
    start_idx = i * window_size
    end_idx = (i + 1) * window_size
    plt.axvspan(start_idx, end_idx, facecolor=background_colors[i % len(background_colors)], alpha=0.2)

plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Generated "Ground-Truth" Signal')
plt.grid(True)
plt.show()
